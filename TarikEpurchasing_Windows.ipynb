# %% [markdown]
# # Tarik Data E-Purchasing
# Dibuat oleh : **Kurnia Ramadhan** (Biro PBJ Setda Prov. Kalbar - Tahun 2022)

# %%
# Import Library Utama
import datetime
import os
import wget
import pandas as pd

x = datetime.datetime.now()

#print(x.year)
#print(x.month)
#print(x.day)
#print(x.hour)
#print(x.minute)

# %%
# SETTING DIREKTORI & URL API JSON LKPP #
# Sampel API JSON: https://inaproc.lkpp.go.id/isb/api/35a90e23-7000-4914-a53b-70ba872dc142/json/180003027/PaketPenyediaOpt1618/tipe/4:12/parameter/2021:D197

## Kode RUP dan Kode LPSE ##
## Silahkan disesuaikan dengan kode RUP dan kode LPSE dari UKPBJ anda ##
#kodeRUP = "D197"
#kodeLPSE = "97" 

## Setting Direktori tempat menyimpan file di Google Drive ##
### Silahkan disesuaikan dengan settingan Google Drive di PC anda ###
direktori = "G:/My Drive/Coding/Python/Project/dash-ukpbj/parquet/"
#direktoricsv = "G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/"
#direktorixlsx = "G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/"
#direktoriftr = "G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/"

#direktorigabung = "G:/My Drive/Coding/Python/Project/dash-ukpbj/data/"

## Data ePurchasing
### 1 - Data Katalog - Dibiarkan saja
urlTRXKAT = "https://isb.lkpp.go.id/isb/api/c3dee072-3ef1-4b24-8b1d-7239e1ccd7e9/json/736987130/Ecat-PaketEPurchasing/tipe/4:12/parameter/"
urlTRXKATAYANG = "https://isb.lkpp.go.id/isb/api/4bb5a044-79db-4041-9545-acc042ddc1b2/json/736990830/Ecat-ProdukTayangKatalogLokalSektoral/tipe/12/parameter/"
urlTRXKATKOM = "https://isb.lkpp.go.id/isb/api/cd5fecd9-2bab-4b43-8687-98c5f6604319/json/736987127/Ecat-KomoditasDetail/tipe/4/parameter/"

### 2 - Data Toko Daring
urlDARING = "https://inaproc.lkpp.go.id/isb/api/4eb548e7-39cc-4ec8-a4db-8c4d702e0e02/json/736989901/TokoDaringRealisasi/tipe/12:4/parameter/"

# %%
# Fungsi untuk download data JSON
def unduhJSONTRXKATALOG(jenisdata,kode,tahun):

  if kode == "PROV":
    kodeRUP = "D197"
    kodeLPSE = "97"
  if kode == "SKW":
    kodeRUP = "D200"
    kodeLPSE = "132"
  if kode == "PTK":
    kodeRUP = "D199"
    kodeLPSE = "62"
  if kode == "SBS":
    kodeRUP = "D208"
    kodeLPSE = "354"
  if kode == "MPW":
    kodeRUP = "D552"
    kodeLPSE = "118"
  if kode == "KKR":
    kodeRUP = "D202"
    kodeLPSE = "188"
  if kode == "BKY":
    kodeRUP = "D206"
    kodeLPSE = "444"
  if kode == "LDK":
    kodeRUP = "D205"
    kodeLPSE = "496"  
  if kode == "SGU":
    kodeRUP = "D204"
    kodeLPSE = "298"
  if kode == "SKD":
    kodeRUP = "D198"
    kodeLPSE = "175"
  if kode == "STG":
    kodeRUP = "D211"
    kodeLPSE = "345"
  if kode == "MLW":
    kodeRUP = "D210"
    kodeLPSE = "540"
  if kode == "KPH":
    kodeRUP = "D209"
    kodeLPSE = "488"
  if kode == "KTP":
    kodeRUP = "D201"
    kodeLPSE = "110"
  if kode == "KKU":
    kodeRUP = "D207"
    kodeLPSE = "393"
  if kode == "KALSEL":
    kodeRUP = "D212"
    kodeLPSE = "181"

  if jenisdata == "trxkatalog":
    # Download Data Transaksi Katalog
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url Data Transaksi Katalog
    urlfile = urlTRXKAT + kodeJSON

  if jenisdata == "prodkatalog":
    # Download Data Produk Katalog Tayang
    kodeJSON = kodeRUP
    # Variabel url Data Produk Tayang
    urlfile = urlTRXKATAYANG + kodeJSON

  if jenisdata == "daring":
    # Download Data Transaksi Toko Daring
    kodeJSON = kodeRUP + ":" + tahun
    # Variabel url Toko Daring
    urlfile = urlDARING + kodeJSON

  fileJSON = direktori + kode + "/" + jenisdata + tahun + ".json"
  filePARQUET = direktori + kode + "/" + jenisdata + tahun + ".parquet"

  ## Download dana Konversi Data ##
  if tahun != "2022":
    if (os.path.exists(fileJSON) or os.path.exists(filePARQUET)):
      print("Data JSON, dan PARQUET tahun " + tahun + " sudah ada, tidak perlu di download lagi !")
    else:
      if (wget.download(urlfile,fileJSON)):
        print("Download data " + kode + " - " + jenisdata + " Tahun " + tahun + " Berhasil.")
        # Konversi data JSON to CSV, EXCEL, dan FTR
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Terjadi masalah saat membaca file JSON ", fileJSON)
        try:
          dfUnduh.to_parquet(filePARQUET)
        except:
          print("Terjadi masalah saat konversi file JSON ke PARQUET ", filePARQUET)
      else:
        print("Download data " + kode + " - " + jenisdata + " Tahun " + tahun + " Gagal.")        
  else:
    if (os.path.exists(fileJSON) or os.path.exists(filePARQUET)):
      try:
        os.remove(fileJSON)
      except:
        print("Terjadi masalah saat hapus file ", fileJSON)
      try:
        os.remove(filePARQUET)
      except:
        print("Terjadi masalah saat hapus file ", filePARQUET)
 
      if (wget.download(urlfile,fileJSON)):
        print("Sukses Update Data JSON, dan PARQUET - " + kode + " - " + jenisdata + " Tahun " + tahun + ".")
        # Konversi data JSON to PARQUET
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Terjadi masalah saat membaca file JSON ", fileJSON)
        try:
          dfUnduh.to_parquet(filePARQUET)
        except:
          print("Terjadi masalah saat konversi file JSON ke PARQUET ", filePARQUET)
      else:
        print("Gagal Update Data JSON, dan PARQUET - " + kode + " - " + jenisdata + " Tahun " + tahun + ".")
    else:
      if (wget.download(urlfile,fileJSON)):
        print("Download data " + kode + " - " + jenisdata + " Tahun " + tahun + " Berhasil.")
        # Konversi data JSON to PARQUET
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Terjadi masalah saat membaca file JSON ", fileJSON)
        try:
          dfUnduh.to_parquet(filePARQUET)
        except:
          print("Terjadi masalah saat konversi file JSON ke PARQUET ", filePARQUET)
      else:
        print("Download data " + kode + " - " + jenisdata + " Tahun " + tahun + " Gagal.")

# %%
pilihs = ["tarikdatakatalog", "gabungdatakatalog", "tarikdatakomoditas", "katalogdetail"]
for pilih in pilihs:

  if pilih == "tarikdatakatalog":

    # Unduh Data E-Purchasing
    kldis = ["PROV", "PTK", "KKR", "MPW", "SKW", "SBS", "BKY", "LDK", "SGU", "SKD", "STG", "MLW", "KPH", "KKU", "KTP"]
    jenisdatas = ["trxkatalog", "prodkatalog", "daring"]
    tahuns = ["2019","2020","2021","2022"]

    #kldi = input("KLDI ? (Format: PROV, PTK, KKR ...")
    #kode = kldi.upper()

    for kode in kldis:
      for jenisdata in jenisdatas:
        for tahun in tahuns:
          unduhJSONTRXKATALOG(jenisdata,kode,tahun)

  elif pilih == "gabungdatakatalog":

    # Gabung Data Transaksi E-Katalog dan Toko Daring
    provs = ["PROV", "PTK", "KKR", "MPW", "SKW", "SBS", "BKY", "LDK", "SGU", "SKD", "STG", "MLW", "KPH", "KKU", "KTP"]

    trxlist = []
    prodlist = []
    tdlist = []

    for prov in provs:
      # Gabung Data Transaksi Katalog
      trxPARQUET = direktori + prov + "/trxkatalog2022.parquet"
      if (os.path.exists(trxPARQUET)):
        trxkat = pd.read_parquet(trxPARQUET)       
        trxlist.append(trxkat)
      # Gabung Data Produk Katalog
      prodPARQUET = direktori + prov + "/prodkatalog2022.parquet"
      if (os.path.exists(prodPARQUET)):
        prodkat = pd.read_parquet(prodPARQUET)
        prodlist.append(prodkat)
      # Gabung Data Transaksi Toko Daring
      daringPARQUET = direktori + prov + "/daring2022.parquet"
      if (os.path.exists(daringPARQUET)):
        trxtd = pd.read_parquet(daringPARQUET)
        tdlist.append(trxtd)
  
    fileKATGABPARQUET = direktori + "trxkatalog.parquet"
    filePRODGABPARQUET = direktori + "prodkatalog.parquet"
    fileDARINGGABPARQUET = direktori + "daring.parquet"

    ## Gabung Data Transaksi E-Katalog
    try:
      trxgabung = pd.concat(trxlist)
      print("Penggabungan data E-Katalog Kalbar Sukses")   
    except:
      print("Terjadi masalah saat menggabungkan data E-Katalog Kalbar")
    try:
      trxgabung.to_parquet(fileKATGABPARQUET)
      print("Konversi Data E-Katalog Kalbar ke format Parquet Sukses")
    except:
      print("Terjadi masalah saat konversi Data E-Katalog Kalbar ke format Parquet")

    ## Gabung Data Produk E-Katalog
    try:
      prodgabung = pd.concat(prodlist)
      print("Penggabungan data Produk E-Katalog Kalbar Sukses")   
    except:
      print("Terjadi masalah saat menggabungkan data Produk E-Katalog Kalbar")
    try:
      prodgabung.to_parquet(filePRODGABPARQUET)
      print("Konversi Data Produk E-Katalog Kalbar ke format Parquet Sukses")
    except:
      print("Terjadi masalah saat konversi Data Produk E-Katalog Kalbar ke format Parquet")

    ## Gabung Data Transaksi Toko Daring
    try:
      daringgabung = pd.concat(tdlist)
      print("Penggabungan data Transaksi Toko Daring Kalbar Sukses")   
    except:
      print("Terjadi masalah saat menggabungkan data Transaksi Toko Daring Kalbar")
    try:
      daringgabung.to_parquet(fileDARINGGABPARQUET)
      print("Konversi data Transaksi Toko Daring Kalbar ke format Parquet Sukses")
    except:
      print("Terjadi masalah saat konversi data Transaksi Toko Daring Kalbar ke format Parquet")

  elif pilih == "tarikdatakomoditas":

    # Tarik Data Komoditas
    trxkatalogdir = direktori + "trxkatalog.parquet"
    trxkatalog = pd.read_parquet(trxkatalogdir)
    
    fileKOMDETPARQUET = direktori + "komoditasdetail.parquet"
    
    kodekomoditas = trxkatalog['kd_komoditas'].unique()
    komoditasgab = []
    for kodekom in kodekomoditas:
      urlkomoditi = urlTRXKATKOM + str(kodekom)
      komoditas = pd.read_json(urlkomoditi)
      komoditasgab.append(komoditas)

    try:
      komoditasdetail = pd.concat(komoditasgab)
      print("Penggabungan data Komoditas Detail Kalbar Sukses")
    except:
      print("Terjadi masalah saat menggabungkan data Komoditas Detail Kalbar")
    try:
      komoditasdetail.to_parquet(fileKOMDETPARQUET)
      print("Konversi Data Komoditas Detail Kalbar ke format Parquet Sukses")
    except:
      print("Terjadi masalah saat konversi Data Komoditas Detail Kalbar ke format Parquet")

  elif pilih == "katalogdetail":

    # Tarik Data Transaksi
    trxkatalogdir = direktori + "trxkatalog.parquet"
    trxkatalog = pd.read_parquet(trxkatalogdir)
    # Tarik Data Detail Komoditas
    komoditasdetaildir = direktori + "komoditasdetail.parquet"
    komoditasdetail = pd.read_parquet(komoditasdetaildir)

    fileKATALOGDETAILPARQUET = direktori + "katalogdetail.parquet"

    try:
      katalog_detail = trxkatalog.merge(komoditasdetail, how='left', on='kd_komoditas')
      print("Penggabungan data Transaksi dan Detail Komoditas Katalog Sukses")
    except:
      print("Terjadi masalah saat menggabungkan data Katalog Detail Kalbar")

    try:
      katalog_detail.to_parquet(fileKATALOGDETAILPARQUET)
      print("Konversi Data Katalog Detail Kalbar ke format Parquet Sukses")
    except:
      print("Terjadi masalah saat konversi data Katalog Detail Kalbar")

  else:
    print("Perintah yang anda inginkan tidak tersedia ... !")
# Out:
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PROV/trxkatalog2022.xlsx
# Sukses Update Data JSON, CSV, EXCEL dan FTR - PROV - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PROV/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Download data PROV - prodkatalog Tahun 2022 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PROV/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - PROV - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PROV/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - PTK - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PTK/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - PTK - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PTK/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - PTK - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/PTK/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKR - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKR/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKR - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKR/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKR - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKR/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MPW - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MPW/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MPW - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MPW/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MPW - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MPW/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKW - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKW/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKW - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKW/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKW - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKW/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SBS - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SBS/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SBS - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SBS/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SBS - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SBS/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - BKY - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BKY/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - BKY - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BKY/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - BKY - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BKY/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - LDK - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/LDK/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - LDK - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/LDK/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - LDK - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/LDK/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SGU - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SGU/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SGU - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SGU/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SGU - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SGU/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKD - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKD/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKD - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKD/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/SKD/daring2022.csv
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKD/daring2022.xlsx
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/SKD/daring2022.ftr
# Sukses Update Data JSON, CSV, EXCEL dan FTR - SKD - daring Tahun 2022.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/SKD/daring2022.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/SKD/daring2022.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/SKD/daring2022.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/SKD/daring2022.ftr
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - STG - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/STG/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - STG - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/STG/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/STG/daring2022.csv
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/STG/daring2022.xlsx
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/STG/daring2022.ftr
# Sukses Update Data JSON, CSV, EXCEL dan FTR - STG - daring Tahun 2022.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/STG/daring2022.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/STG/daring2022.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/STG/daring2022.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/STG/daring2022.ftr
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MLW - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MLW/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MLW - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MLW/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - MLW - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/MLW/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KPH - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KPH/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KPH - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KPH/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KPH - daring Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KPH/daring2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKU - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKU/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKU - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKU/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/KKU/daring2022.csv
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKU/daring2022.xlsx
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/KKU/daring2022.ftr
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KKU - daring Tahun 2022.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/KKU/daring2022.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/KKU/daring2022.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KKU/daring2022.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/KKU/daring2022.ftr
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KTP - trxkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KTP/trxkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KTP - prodkatalog Tahun 2022.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KTP/prodkatalog2022.xlsx
# Data JSON, CSV, EXCEL dan FTR tahun 2019 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2020 sudah ada, tidak perlu di download lagi !
# Data JSON, CSV, EXCEL dan FTR tahun 2021 sudah ada, tidak perlu di download lagi !
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/KTP/daring2022.csv
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KTP/daring2022.xlsx
# Terjadi masalah saat hapus file  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/KTP/daring2022.ftr
# Sukses Update Data JSON, CSV, EXCEL dan FTR - KTP - daring Tahun 2022.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/KTP/daring2022.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/KTP/daring2022.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/KTP/daring2022.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/KTP/daring2022.ftr
# Download data BPK - trxkatalog Tahun 2019 Berhasil.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/BPK/trxkatalog2019.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/BPK/trxkatalog2019.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/trxkatalog2019.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/BPK/trxkatalog2019.ftr
# Download data BPK - trxkatalog Tahun 2020 Berhasil.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/BPK/trxkatalog2020.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/BPK/trxkatalog2020.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/trxkatalog2020.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/BPK/trxkatalog2020.ftr
# Download data BPK - trxkatalog Tahun 2021 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/trxkatalog2021.xlsx
# Download data BPK - trxkatalog Tahun 2022 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/trxkatalog2022.xlsx
# Download data BPK - prodkatalog Tahun 2019 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/prodkatalog2019.xlsx
# Download data BPK - prodkatalog Tahun 2020 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/prodkatalog2020.xlsx
# Download data BPK - prodkatalog Tahun 2021 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/prodkatalog2021.xlsx
# Download data BPK - prodkatalog Tahun 2022 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/prodkatalog2022.xlsx
# Download data BPK - daring Tahun 2019 Berhasil.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/BPK/daring2019.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/BPK/daring2019.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/daring2019.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/BPK/daring2019.ftr
# Download data BPK - daring Tahun 2020 Berhasil.
# Terjadi masalah saat membaca file JSON  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/json/BPK/daring2020.json
# Terjadi masalah saat konversi file JSON ke CSV  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/csv/BPK/daring2020.csv
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/daring2020.xlsx
# Terjadi masalah saat konversi file JSON ke Feather  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/ftr/BPK/daring2020.ftr
# Download data BPK - daring Tahun 2021 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/daring2021.xlsx
# Download data BPK - daring Tahun 2022 Berhasil.
# Terjadi masalah saat konversi file JSON ke EXCEL  G:/My Drive/Coding/Python/Project/dash-ukpbj/data/excel/BPK/daring2022.xlsx
# Penggabungan data E-Katalog Kalbar Sukses
# Terjadi masalah saat konversi Data E-Katalog Kalbar ke format Excel
# Penggabungan data Produk E-Katalog Kalbar Sukses
# Terjadi masalah saat konversi Data Produk E-Katalog Kalbar ke format Excel
# Penggabungan data Transaksi Toko Daring Kalbar Sukses
# Terjadi masalah saat konversi data Transaksi Toko Daring Kalbar ke format Excel
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     137 try:
# --> 138     module = importlib.import_module(name)
#     139 except ImportError:
#
# File c:\Users\krama\anaconda3\envs\ular\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In [22], line 89
#      85 elif pilih == "tarikdatakomoditas":
#      86
#      87   # Tarik Data Komoditas
#      88   trxkatalogdir = direktorigabung + "trxkatalog.xlsx"
# ---> 89   trxkatalog = pd.read_excel(trxkatalogdir)
#      91   fileKOMDETXLSX = direktorigabung + "komoditasdetail.xlsx"
#      93   kodekomoditas = trxkatalog['kd_komoditas'].unique()
#
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\io\excel\_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1416 self.engine = engine
#    1417 self.storage_options = storage_options
# -> 1419 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\io\excel\_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     509 def __init__(
#     510     self,
#     511     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     512     storage_options: StorageOptions = None,
#     513 ) -> None:
#     514     """
#     515     Reader using openpyxl engine.
#     516
#    (...)
#     522         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     523     """
# --> 524     import_optional_dependency("openpyxl")
#     525     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\krama\anaconda3\envs\ular\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     139 except ImportError:
#     140     if errors == "raise":
# --> 141         raise ImportError(msg)
#     142     else:
#     143         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
