# %% [markdown]
# # **Tarik Data RUP DLL**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Library

# %% [markdown]
# **Install Library System**

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=73589da4d51ff5bda606cbd202740e387eaa18a739475752d3021eb6b9bf25c3
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %% [markdown]
# **Import Library Penting**

# %%
# Import Library Data Analysis
import datetime
import os
import wget
import pandas as pd

# %%
x = datetime.datetime.now()
print(x.year)
print(x.month)
print(x.day)
# Out:
# 2022
# 11
# 30

# %% [markdown]
# ## URL API JSON LKPP

# %%
### URL API JSON LKPP - RUP ###
### Sampel: https://inaproc.lkpp.go.id/isb/api/35a90e23-7000-4914-a53b-70ba872dc142/json/180003027/PaketPenyediaOpt1618/tipe/4:12/parameter/2021:D197

## Setting Direktori dan nama file berdasarkan Tahun
direktorijson = "/content/drive/MyDrive/Colab Notebooks/Project/TarikData/data/json/"
direktoricsv = "/content/drive/MyDrive/Colab Notebooks/Project/TarikData/data/csv/"
direktorixlsx = "/content/drive/MyDrive/Colab Notebooks/Project/TarikData/data/excel/"
direktoriftr = "/content/drive/MyDrive/Colab Notebooks/Project/TarikData/data/ftr/"

## Setting Kode UKPBJ
# kode = "D197"

## Daftar LPSE
urlLPSE = "https://satudata.inaproc.id/service/daftarLPSE"

## Data Sipraja
urlSIPRAJA = "https://sipraja.kalbarprov.go.id/api/pakets-karo/"

## Data Sanggah
urlSANGGAH = "https://inaproc.lkpp.go.id/isb/api/74bae564-8441-414d-82af-ab79c6cb642d/json/444890344/SanggahDanSanggahBandingSPSE/tipe/4:12/parameter/"

## Data Toko Daring
urlDARING = "https://inaproc.lkpp.go.id/isb/api/4eb548e7-39cc-4ec8-a4db-8c4d702e0e02/json/736989901/TokoDaringRealisasi/tipe/12:4/parameter/"

## DATA SPSE
### - 1 - Data Tender
urlDTP = "https://inaproc.lkpp.go.id/isb/api/6c809975-322a-4bac-b806-3bff874f8e4c/json/180505303/TenderPengumumanDetailSPSE/tipe/4:12/parameter/"
urlDTS = "https://inaproc.lkpp.go.id/isb/api/079b6694-293d-4f18-a83e-df5a49205050/json/180505337/TenderSelesaiDetailSPSE/tipe/4:12/parameter/"
urlDTKS = "https://isb.lkpp.go.id/isb/api/9dfeef08-1ac8-47d5-84ae-53b2ca618b3d/json/736985911/TenderEkontrakSPPBJspse/tipe/4:4/parameter/"
urlDTKB = "https://isb.lkpp.go.id/isb/api/a72661ed-878e-4d36-b8ed-610a6cef20b5/json/736985843/TenderEkontrakBAPbastSPSE/tipe/4:4/parameter/"
urlDTPO = "https://isb.lkpp.go.id/isb/api/084ed69c-45ec-4669-823e-cbb0a028e8fd/json/201782418/PokjaPerTenderSPSE/tipe/4:4/parameter/"
urlDTPPK = "https://isb.lkpp.go.id/isb/api/f8bff957-f6f9-46a2-a678-a83724c45961/json/201782404/PPKperTenderSPSE/tipe/4:4/parameter/"

### - 2 - Data Non Tender
urlDNTKS = "https://isb.lkpp.go.id/isb/api/03c0390c-8007-427b-997c-04372c9eef7b/json/736985946/NonTenderEkontrakSPPBJspse/tipe/4:4/parameter/"
urlDNTS = "https://isb.lkpp.go.id/isb/api/32846be4-ea01-4c41-b6ba-eab8e1123947/json/736985924/NonTenderSelesaiDetailSPSE/tipe/4:4/parameter/"
urlDNTP = "https://isb.lkpp.go.id/isb/api/19bf6b57-ab87-450e-9a5f-62c6d2d1933f/json/736985866/NonTenderPengumumanDetailSPSE/tipe/4:4/parameter/"
urlDNTKB = "https://isb.lkpp.go.id/isb/api/4fb8404c-253b-4301-a95e-49e4426bc4a0/json/736985820/NonTenderEkontrakBAPbastSPSE/tipe/4:4/parameter/"
urlDNTPP = "https://isb.lkpp.go.id/isb/api/663fad6b-1e02-42c9-87a8-f93f0a231468/json/201782484/PPperNonTenderSPSE/tipe/4:4/parameter/"
urlDNTPO = "https://isb.lkpp.go.id/isb/api/779fdac2-adb2-46e3-8efc-90f36f7a1b4d/json/201782475/PokjaPerNonTenderSPSE/tipe/4:4/parameter/"
urlDNTPPK = "https://isb.lkpp.go.id/isb/api/2e698a9a-8876-4a0b-bdf7-722b960d5536/json/201782467/PPKperNonTenderSPSE/tipe/4:4/parameter/"

### - 3 - Pencatatan Non Tender
urlPNT = "https://isb.lkpp.go.id/isb/api/f2a88a73-7ccb-470f-b458-577a85cabdd1/json/736985889/PencatatanNonTenderSPSE/tipe/4:4/parameter/"

### - 4 - Pencatatan Swakelola
urlPSW = "https://isb.lkpp.go.id/isb/api/fa0a34ab-4eff-4b2a-be7c-921f4cd762db/json/736985832/PencatatanSwakelolaSPSE/tipe/4:4/parameter/"

### - 5 - Data E-Katalog
urlDEPEP = "https://isb.lkpp.go.id/isb/api/c3dee072-3ef1-4b24-8b1d-7239e1ccd7e9/json/736987130/Ecat-PaketEPurchasing/tipe/4:12/parameter/"
urlDETAYANG = "https://isb.lkpp.go.id/isb/api/4bb5a044-79db-4041-9545-acc042ddc1b2/json/736990830/Ecat-ProdukTayangKatalogLokalSektoral/tipe/12/parameter/"
urlDEIUPK = "https://isb.lkpp.go.id/isb/api/439f7d18-4a6b-4008-8744-c57453f32162/json/736985957/InformasiUtamaPaketKLDItahun/tipe/12:4/parameter/"

## Data SIRUP
### - 1 - Data Struktur Anggaran
urlRSAP = "https://isb.lkpp.go.id/isb/api/1da1a903-fd09-4383-91e5-d0ba579b2e31/json/736987131/RUPStrukturAnggaranPemda1221/tipe/4:12/parameter/"
urlPMR = "https://isb.lkpp.go.id/isb/api/350f3b43-fbc9-48a4-83f6-f775fd826115/json/201782357/ProgramMasterRUP/tipe/4:12/parameter/"
urlKMR = "https://isb.lkpp.go.id/isb/api/00662374-6f93-4925-9789-1a8502b7f704/json/201782340/KegiatanMasterRUP/tipe/4:12/parameter/"
urlROAMR = "https://isb.lkpp.go.id/isb/api/d66221e8-b17f-4177-bb66-9541ae7feb9b/json/201782328/RinciObjekAkunMasterRUP/tipe/4:12/parameter/"
urlOAMR = "https://isb.lkpp.go.id/isb/api/872163a2-21e0-432f-b31d-b697999f0ee8/json/201782310/ObjekAkunMasterRUP/tipe/4:12/parameter/"

### - 2 - Data Penyedia
urlPP = "https://inaproc.lkpp.go.id/isb/api/35a90e23-7000-4914-a53b-70ba872dc142/json/180003027/PaketPenyediaOpt1618/tipe/4:12/parameter/"
#urlPPD = "https://inaproc.lkpp.go.id/isb/api/1d24d556-e7d9-4326-a196-4441fdafd86c/json/23233190/PengumumanPenyediaDaerah1618/tipe/4:12/parameter/"
urlPAP = "https://inaproc.lkpp.go.id/isb/api/1b10377b-0a8d-4f05-9284-995e4572703d/json/180014351/PaketAnggaranPenyedia1618/tipe/4:12/parameter/"

### - 3 - Data Swakelola
urlPS = "https://inaproc.lkpp.go.id/isb/api/d6941032-e0f8-4714-be95-7697b57ddc36/json/180003099/PaketSwakelolaOpt1618/tipe/4:12/parameter/"
#urlPSD = "https://inaproc.lkpp.go.id/isb/api/c13c942d-a1d3-4599-b33b-369e986a7a2b/json/23233199/PengumumanSwakelolaDaerah1618/tipe/4:12/parameter/"
#urlPAS = "https://inaproc.lkpp.go.id/isb/api/ada49008-929f-432b-b3bc-f8af49d4678d/json/180014401/PaketAnggaranSwakelola1618/tipe/4:12/parameter/"

# %% [markdown]
# ## Kumpulan Fungsi

# %%
# Fungsi Download JSON
def unduhJSON(jenisdata,kode,tahun):

  if kode == "PROV":
    kodeRUP = "D197"
    kodeLPSE = "97"
  if kode == "SKW":
    kodeRUP = "D200"
    kodeLPSE = "132"
  if kode == "PTK":
    kodeRUP = "D199"
    kodeLPSE = "62"
  if kode == "SBS":
    kodeRUP = "D208"
    kodeLPSE = "354"
  if kode == "MPW":
    kodeRUP = "D552"
    kodeLPSE = "118"
  if kode == "KKR":
    kodeRUP = "D202"
    kodeLPSE = "188"
  if kode == "BKY":
    kodeRUP = "D206"
    kodeLPSE = "444"
  if kode == "LDK":
    kodeRUP = "D205"
    kodeLPSE = "496"  
  if kode == "SGU":
    kodeRUP = "D204"
    kodeLPSE = "298"
  if kode == "SKD":
    kodeRUP = "D198"
    kodeLPSE = "175"
  if kode == "STG":
    kodeRUP = "D211"
    kodeLPSE = "345"
  if kode == "MLW":
    kodeRUP = "D210"
    kodeLPSE = "540"
  if kode == "KPH":
    kodeRUP = "D209"
    kodeLPSE = "488"
  if kode == "KTP":
    kodeRUP = "D201"
    kodeLPSE = "110"
  if kode == "KKU":
    kodeRUP = "D207"
    kodeLPSE = "393"
  if kode == "KALSEL":
    kodeRUP = "D212"
    kodeLPSE = "181"

  ### Setting Variabel
  if jenisdata == "sipraja":

    # Dwonload data Sipraja
    kodeJSON = tahun
    # Variabel url Sipraja
    urlfile = urlSIPRAJA + kodeJSON

  if jenisdata == "sanggah":

    # Download data Sanggah
    #kodeJSON = tahun + ":" + kode[2:]
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url Sanggah
    urlfile = urlSANGGAH + kodeJSON

  if jenisdata == "daring":

    # Download data Toko Daring
    kodeJSON = kodeRUP + ":" + tahun
    # Variabel url Toko Daring
    urlfile = urlDARING + kodeJSON

  if jenisdata == "sirupdp":
    # Download data SIRUP Paket Penyedia
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Paket Penyedia
    urlfile = urlPP + kodeJSON

  if jenisdata == "siruppap":
    # Download data SIRUP Paket Penyedia
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Paket Penyedia
    urlfile = urlPAP + kodeJSON    

  if jenisdata == "sirupdsw":
    # Download data SIRUP Swakelola  
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Swakelola
    urlfile = urlPS + kodeJSON

  if jenisdata == "pntender":
    # Download data Pencatatan Non Tender
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url Pencatatan Non Tender
    urlfile = urlPNT + kodeJSON

  if jenisdata == "pswakelola":
    # Download data Pencatatan Swakelola
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url Pencatatan Non Tender
    urlfile = urlPSW + kodeJSON

  if jenisdata == "sirupdsa_rsap":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlRSAP + kodeJSON
 
  if jenisdata == "sirupdsa_pmr":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlPMR + kodeJSON

  if jenisdata == "sirupdsa_kmr":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlKMR + kodeJSON

  if jenisdata == "sirupdsa_roamr":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlROAMR + kodeJSON

  if jenisdata == "sirupdsa_oamr":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlOAMR + kodeJSON

  if jenisdata == "dtender_dtp":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTP + kodeJSON

  if jenisdata == "dtender_dts":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTS + kodeJSON

  if jenisdata == "dtender_dtks":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTKS + kodeJSON

  if jenisdata == "dtender_dtkb":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTKB + kodeJSON

  if jenisdata == "dtender_dtpo":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTPO + kodeJSON

  if jenisdata == "dtender_dtppk":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDTPPK + kodeJSON

  if jenisdata == "dntender_dntks":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTKS + kodeJSON

  if jenisdata == "dntender_dnts":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTS + kodeJSON

  if jenisdata == "dntender_dntp":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTP + kodeJSON

  if jenisdata == "dntender_dntkb":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTKB + kodeJSON

  if jenisdata == "dntender_dntpp":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTPP + kodeJSON

  if jenisdata == "dntender_dntpo":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTPO + kodeJSON

  if jenisdata == "dntender_dntppk":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeLPSE
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDNTPPK + kodeJSON

  if jenisdata == "dkatalog_depep":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDEPEP + kodeJSON

  if jenisdata == "dkatalog_detayang":
    # Download Data Katalog Produk Tayang
    kodeJSON = kodeRUP
    # Variabel url Katalog Produk Tayang
    urlfile = urlDETAYANG + kodeJSON

  if jenisdata == "dkatalog_deiupk":
    # Download data SIRUP Struktur Anggaran
    kodeJSON = tahun + ":" + kodeRUP
    # Variabel url SIRUP Struktur Anggaran
    urlfile = urlDEIUPK + kodeJSON

  fileJSON = direktorijson + kode + "/" + jenisdata + tahun + ".json"
  fileCSV = direktoricsv + kode + "/" + jenisdata + tahun + ".csv"
  fileXLSX = direktorixlsx + kode + "/" + jenisdata + tahun + ".xlsx"
  fileFTR = direktoriftr + kode + "/" + jenisdata + tahun + ".ftr"

  ### Download Data ###
  if tahun == "2022":
    if (os.path.exists(fileJSON) or os.path.exists(fileCSV) or os.path.exists(fileXLSX) or os.path.exists(fileFTR)):
      try:
        os.remove(fileJSON)
      except:
        print("Error saat hapus file ", fileJSON)
      try:  
        os.remove(fileCSV)
      except:
        print("Error saat hapus file ", fileCSV) 
      try: 
        os.remove(fileXLSX)
      except:
        print("Error saat hapus file", fileXLSX)
      try:
        os.remove(fileFTR)
      except:
        print("Error saat hapus file ", fileFTR)

      if (wget.download(urlfile,fileJSON)):
        print("Sukses update data " + kode + " - " + jenisdata + " Tahun " + tahun + ".")
        # Konversi data JSON to CSV dan FTR
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Error Read JSON ", fileJSON)
        try:
          dfUnduh.to_csv(fileCSV)
        except:
          print("Error konversi ", fileCSV)
        try:
          dfUnduh.to_excel(fileXLSX, index = False)
        except:
          print("Error konversi ", fileXLSX)    
        try:
          dfUnduh.to_feather(fileFTR)
        except:
          print("Error konversi ", fileFTR)
      else:
        print("Gagal update data " + kode + " - " + jenisdata + " Tahun " + tahun + ".")

    else:

      if (wget.download(urlfile,fileJSON)):
        print("Download Data " + kode + " - " + jenisdata + " Tahun " + tahun + " berhasil.")
        # Konversi data JSON to CSV dan FTR
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Error Read JSON ", fileJSON)
        try:
          dfUnduh.to_csv(fileCSV)
        except:
          print("Error konversi ", fileCSV)
        try:
          dfUnduh.to_excel(fileXLSX, index = False)
        except:
          print("Error konversi ", fileXLSX)    
        try:
          dfUnduh.to_feather(fileFTR)
        except:
          print("Error konversi ", fileFTR)
      else:
        print("Download Data " + kode + " - " + jenisdata + " Tahun " + tahun + " gagal.")
  
  else:

    if (os.path.exists(fileJSON) or os.path.exists(fileCSV) or os.path.exists(fileXLSX) or os.path.exists(fileFTR)):
      print("Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !") 
    else:
      if (wget.download(urlfile,fileJSON)):
        print("Download Data " + kode + " - " + jenisdata + " Tahun " + tahun + " berhasil.")
        # Konversi data JSON to CSV dan FTR
        try:
          dfUnduh = pd.read_json(fileJSON)
        except:
          print("Error Read JSON ", fileJSON)
        try:
          dfUnduh.to_csv(fileCSV)
        except:
          print("Error konversi ", fileCSV)
        try:
          dfUnduh.to_excel(fileXLSX, index = False)
        except:
          print("Error konversi ", fileXLSX)    
        try:
          dfUnduh.to_feather(fileFTR)
        except:
          print("Error konversi ", fileFTR)
      else:
        print("Download Data " + kode + " - " + jenisdata + " Tahun " + tahun + " gagal.")

# %% [markdown]
# ## Unduh Data

# %%
kldis = ["PROV", "PTK", "KKR", "MPW", "SKW", "SBS", "BKY", "LDK", "SGU", "SKD", "STG", "MLW", "KPH", "KKU", "KTP"]
jenisdatas = ["sipraja", "sanggah", "daring", "sirupdp", "siruppap", "sirupdsw", "pntender", "pswakelola", "sirupdsa_rsap", "sirupdsa_pmr", "sirupdsa_kmr", "sirupdsa_roamr", "sirupdsa_oamr", 
              "dtender_dtp", "dtender_dts", "dtender_dtks", "dtender_dtkb", "dtender_dtpo", "dtender_dtppk", "dntender_dntks", "dntender_dnts", 
              "dntender_dntp", "dntender_dntkb", "dntender_dntpp", "dntender_dntpo", "dntender_dntppk", "dkatalog_depep", "dkatalog_detayang"]
tahuns = ["2019", "2020", "2021", "2022"]

kldi = input("KLDI ? (Format: PROV, PTK, KKR ...")
kode = kldi.upper()

for jenisdata in jenisdatas:
  for tahun in tahuns:
    unduhJSON(jenisdata,kode,tahun)
# Out:
# KLDI ? (Format: PROV, PTK, KKR ...prov
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# Sukses update data PROV - sipraja Tahun 2022.
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# Data JSON, CSV, EXCEL, dan FTR Sudah ada, tidak perlu download lagi !
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
# ...
